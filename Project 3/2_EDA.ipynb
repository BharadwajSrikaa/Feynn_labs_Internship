# %% [markdown]
# ### Performing Exploratory Data Analysis

# %%
import numpy as np
import seaborn as sns
import pandas as pd

# %%
data = pd.read_csv("./clean_data_2.csv")

# %% [markdown]
# ### 1. Getting basic Idea About the Dataset

# %%
data.head()
# Out:
#    mobile_price  disp_size  resolution  os  num_cores  mp_speed  int_memory  \
# 0          8999      16.56     1152000  10          8       2.0          32
# 1          8999      16.56     1152000  10          8       2.0          32
# 2          9999      16.56     1152000  10          8       2.0          64
# 3          9999      16.56     1152000  10          8       2.0          64
# 4         11999      16.51     1152000  10          8       2.0         128
#
#    ram  battery_power  mob_width  mob_height  mob_depth  mob_weight
# 0    3           5000       75.0       164.4       8.95       195.0
# 1    3           5000       75.0       164.4       8.95       195.0
# 2    4           5000       75.0       164.4       8.95       195.0
# 3    4           5000       75.0       164.4       8.95       195.0
# 4    4           5000       75.4       164.4       9.00       199.0

# %%
data.tail()
# Out:
#      mobile_price  disp_size  resolution  os  num_cores  mp_speed  int_memory  \
# 454         13490      14.48     1036800   7          8       2.5          32
# 455          9490      14.48     1036800   7          8       2.5          16
# 456         22990      15.82     2462400   8          8       2.0          64
# 457         13990      16.59     2527200   9          8       2.1         128
# 458         13990      16.59     2527200   9          8       2.1         128
#
#      ram  battery_power  mob_width  mob_height  mob_depth  mob_weight
# 454    3           3180       73.1       150.5        7.7       143.0
# 455    2           3180       73.1       150.5        7.7       143.0
# 456    4           3400       75.3       156.0        7.8       158.0
# 457    4           4020       76.1       162.0        8.3       188.0
# 458    4           4020       76.1       162.0        8.3       188.0

# %%
data.shape
# Out:
# (459, 13)

# %%
data.describe()
# Out:
#        mobile_price   disp_size    resolution          os   num_cores  \
# count    459.000000  459.000000  4.590000e+02  459.000000  459.000000
# mean   16643.448802   15.907647  1.867733e+06    8.681917    7.862745
# std     8701.098364    0.815102  7.096156e+05    0.986326    0.759730
# min     6000.000000   11.940000  5.184000e+05    4.000000    1.000000
# 25%    10999.000000   15.700000  1.094400e+06    8.000000    8.000000
# 50%    14495.000000   16.000000  2.332800e+06    9.000000    8.000000
# 75%    18990.000000   16.510000  2.527200e+06    9.000000    8.000000
# max    60990.000000   17.020000  2.592000e+06   10.000000    8.000000
#
#          mp_speed  int_memory         ram  battery_power   mob_width  \
# count  459.000000  459.000000  459.000000     459.000000  459.000000
# mean     2.118296   87.093682    4.877996    4161.383442   74.228170
# std      0.350997   64.919281    2.082977     615.902516   13.106075
# ...

# %%
data.columns
# Out:
# Index(['mobile_price', 'disp_size', 'resolution', 'os', 'num_cores',
#        'mp_speed', 'int_memory', 'ram', 'battery_power', 'mob_width',
#        'mob_height', 'mob_depth', 'mob_weight'],
#       dtype='object')

# %%
data.nunique()
# Out:
# mobile_price     139
# disp_size         36
# resolution        14
# os                 7
# num_cores          3
# mp_speed          18
# int_memory         7
# ram                7
# battery_power     34
# mob_width         70
# mob_height        81
# mob_depth         55
# mob_weight        62
# dtype: int64

# %% [markdown]
# ### 2. Check whether if it is clean Dataset or Not

# %%
data.isnull().sum()
# Out:
# mobile_price     0
# disp_size        0
# resolution       0
# os               0
# num_cores        0
# mp_speed         0
# int_memory       0
# ram              0
# battery_power    0
# mob_width        0
# mob_height       0
# mob_depth        0
# mob_weight       0
# dtype: int64

# %% [markdown]
# ### 3. Relationship Analysis

# %%
corelation = data.corr()

# %%
sns.heatmap(corelation, xticklabels=corelation.columns, yticklabels=corelation.columns, annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(data)

# %%
 sns.relplot(x="disp_size", y="resolution", hue="mobile_price", data=data)

# %%
 sns.relplot(x="disp_size", y="mob_weight", hue="mobile_price", data=data)

# %%
 sns.relplot(x="battery_power", y="mob_weight", hue="mobile_price", data=data)

# %%
sns.distplot(data["mobile_price"])
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_13320\1129355383.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["mobile_price"])
# <Axes: xlabel='mobile_price', ylabel='Density'>

# %%
sns.displot(data["mobile_price"])

# %%
sns.catplot(x='mobile_price', kind='box', data = data)
